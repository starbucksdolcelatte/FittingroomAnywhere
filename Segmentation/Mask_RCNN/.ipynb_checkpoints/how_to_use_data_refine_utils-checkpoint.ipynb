# %% [markdown]
# # data_refine_utils 라이브러리를 이용하는 방법
# 본 문서에서는 data_refine_utils.py 를 이용하는 방법을 다룹니다.<br>
# 우리 프로젝트에 맞게 만든 라이브러리이므로 유용하게 사용하세요.

# %%
import data_refine_utils as dutils

# DeepFashion2의 validation dataset 경로
original_path_img = "C:/Users/chief/[2]FittingroomAnywhere2/dataset/DeepFashion_original/DeepFashion2/validation/validation//image"
original_path_anno = "C:/Users/chief/[2]FittingroomAnywhere2/dataset/DeepFashion_original/DeepFashion2/validation/validation/annos"

# T-shirt(short sleeve top)만 모아둘 경로
selected_img_path = 'C:/Users/chief/[2]FittingroomAnywhere2/Mask_RCNN/datasets/Tshirt_dataset/all_images'
selected_anno_path = 'C:/Users/chief/[2]FittingroomAnywhere2/Mask_RCNN/datasets/Tshirt_dataset/all_annos'

# T-shirt(short sleeve top)이미지 파일명이 저장된 JSON 파일 경로
img_json_path = 'C:/Users/chief/[2]FittingroomAnywhere2/Mask_RCNN/datasets/Tshirt_dataset/division_shortsleeves.json'

# %%
# JSON 파일 안에 나열된 이미지파일들을
# from_path에서 to_path로 copy & paste 한다.
dutils.img_copy_by_json(original_path_img, selected_img_path, img_json_path)

# %%
# dir_path 안에 있는 모든 이미지 파일명들을 담은 JSON 파일을 생성
dutils.img_filenames_to_json(selected_img_path, img_json_path)

# %%
# selected_img_path 안의 이미지에 해당하는 annotation 파일을
# original_path_anno에서 selected_anno_path로 copy & paste한다.
dutils.anno_copy_by_img(selected_img_path, original_path_anno, selected_anno_path)

# %%
# DeepFashion2 selected annotation 파일들이 있는 디렉토리에서
# 최대 item2까지 확인하여 category_id를 포함하지
# 않는 파일명을 출력 및 리스트로 리턴한다.
dutils.is_not_contains_category(selected_anno_path, category_id=1)
# Out:
# 000234.json ---- item 1 ---- short sleeve top
# 000295.json ---- item 1 ---- short sleeve top
# 000371.json ---- item 1 ---- short sleeve top
# 000469.json ---- item 2 ---- short sleeve top
# 000576.json ---- item 1 ---- short sleeve top
# 000629.json ---- item 1 ---- short sleeve top
# 000719.json ---- item 1 ---- short sleeve top
# 000770.json ---- item 1 ---- short sleeve top
# 001014.json ---- item 1 ---- short sleeve top
# 001121.json ---- item 1 ---- short sleeve top
# 001122.json ---- item 1 ---- short sleeve top
# 001383.json ---- item 1 ---- short sleeve top
# 001452.json ---- item 1 ---- short sleeve top
# 001454.json ---- item 2 ---- short sleeve top
# 001482.json ---- item 1 ---- short sleeve top
# 001511.json ---- item 1 ---- short sleeve top
# 001618.json ---- item 1 ---- short sleeve top
# 002023.json ---- item 1 ---- short sleeve top
# 002027.json ---- item 1 ---- short sleeve top
# 002028.json ---- item 1 ---- short sleeve top
# 002325.json ---- item 1 ---- short sleeve top
# 002647.json ---- item 1 ---- short sleeve top
# 002761.json ---- item 1 ---- short sleeve top
# 002907.json ---- item 1 ---- short sleeve top
# 003039.json ---- item 1 ---- short sleeve top
# 003043.json ---- item 1 ---- short sleeve top
# 003282.json ---- item 1 ---- short sleeve top
# 003317.json ---- item 1 ---- short sleeve top
# 003866.json ---- item 1 ---- short sleeve top
# 003895.json ---- item 1 ---- short sleeve top
# 004436.json ---- item 1 ---- short sleeve top
# 004439.json ---- item 1 ---- short sleeve top
# 004450.json ---- item 1 ---- short sleeve top
# 004525.json ---- item 2 ---- short sleeve top
# 004581.json ---- item 1 ---- short sleeve top
# 004648.json ---- item 1 ---- short sleeve top
# 004649.json ---- item 1 ---- short sleeve top
# 004654.json ---- item 1 ---- short sleeve top
# 004667.json ---- item 1 ---- short sleeve top
# 004800.json ---- item 1 ---- short sleeve top
# 005441.json ---- item 1 ---- short sleeve top
# 005455.json ---- item 2 ---- short sleeve top
# 005859.json ---- item 2 ---- short sleeve top
# 005879.json ---- item 1 ---- short sleeve top
# 005963.json ---- item 1 ---- short sleeve top
# 006122.json ---- item 2 ---- short sleeve top
# 006170.json ---- item 1 ---- short sleeve top
# 006301.json ---- item 1 ---- short sleeve top
# 006541.json ---- item 1 ---- short sleeve top
# 007733.json ---- item 1 ---- short sleeve top
# 008138.json ---- item 1 ---- short sleeve top
# 008503.json ---- item 1 ---- short sleeve top
# 008504.json ---- item 1 ---- short sleeve top
# 009413.json ---- item 1 ---- short sleeve top
# 009447.json ---- item 1 ---- short sleeve top
# 011210.json ---- item 1 ---- short sleeve top
# 011214.json ---- item 1 ---- short sleeve top
# 011215.json ---- item 1 ---- short sleeve top
# 011219.json ---- item 1 ---- short sleeve top
# 011404.json ---- item 1 ---- short sleeve top
# 011501.json ---- item 1 ---- short sleeve top
# 011775.json ---- item 1 ---- short sleeve top
# 011823.json ---- item 1 ---- short sleeve top
# 012333.json ---- item 1 ---- short sleeve top
# 012387.json ---- item 1 ---- short sleeve top
# 012501.json ---- item 1 ---- short sleeve top
# 012503.json ---- item 1 ---- short sleeve top
# 012529.json ---- item 1 ---- short sleeve top
# 012544.json ---- item 2 ---- short sleeve top
# 012548.json ---- item 2 ---- short sleeve top
# 012666.json ---- item 1 ---- short sleeve top
# 012667.json ---- item 1 ---- short sleeve top
# 012668.json ---- item 1 ---- short sleeve top
# 013246.json ---- item 1 ---- short sleeve top
# 013318.json ---- item 1 ---- short sleeve top
# 013411.json ---- item 1 ---- short sleeve top
# 013414.json ---- item 1 ---- short sleeve top
# 013458.json ---- item 1 ---- short sleeve top
# 013603.json ---- item 1 ---- short sleeve top
# 013606.json ---- item 1 ---- short sleeve top
# 013609.json ---- item 1 ---- short sleeve top
# 013612.json ---- item 1 ---- short sleeve top
# 013666.json ---- item 1 ---- short sleeve top
# 013676.json ---- item 1 ---- short sleeve top
# 013678.json ---- item 1 ---- short sleeve top
# 013680.json ---- item 1 ---- short sleeve top
# 013700.json ---- item 1 ---- short sleeve top
# 013702.json ---- item 1 ---- short sleeve top
# 013708.json ---- item 1 ---- short sleeve top
# 013716.json ---- item 1 ---- short sleeve top
# 013869.json ---- item 1 ---- short sleeve top
# 013870.json ---- item 1 ---- short sleeve top
# 013872.json ---- item 1 ---- short sleeve top
# 013874.json ---- item 1 ---- short sleeve top
# 014025.json ---- item 1 ---- short sleeve top
# 014075.json ---- item 1 ---- short sleeve top
# 014107.json ---- item 1 ---- short sleeve top
# 014110.json ---- item 1 ---- short sleeve top
# 014111.json ---- item 1 ---- short sleeve top
# 014127.json ---- item 2 ---- short sleeve top
# 014229.json ---- item 1 ---- short sleeve top
# 014231.json ---- item 1 ---- short sleeve top
# 014233.json ---- item 1 ---- short sleeve top
# 014235.json ---- item 1 ---- short sleeve top
# 014240.json ---- item 1 ---- short sleeve top
# 014242.json ---- item 1 ---- short sleeve top
# 014244.json ---- item 1 ---- short sleeve top
# 014245.json ---- item 1 ---- short sleeve top
# 014247.json ---- item 1 ---- short sleeve top
# 014248.json ---- item 1 ---- short sleeve top
# 014249.json ---- item 1 ---- short sleeve top
# 014250.json ---- item 1 ---- short sleeve top
# 014251.json ---- item 1 ---- short sleeve top
# 014253.json ---- item 1 ---- short sleeve top
# 014254.json ---- item 1 ---- short sleeve top
# 014367.json ---- item 1 ---- short sleeve top
# 014488.json ---- item 2 ---- short sleeve top
# 014492.json ---- item 2 ---- short sleeve top
# 014612.json ---- item 1 ---- short sleeve top
# 014613.json ---- item 1 ---- short sleeve top
# 014615.json ---- item 1 ---- short sleeve top
# 014617.json ---- item 1 ---- short sleeve top
# 014627.json ---- item 2 ---- short sleeve top
# 014631.json ---- item 1 ---- short sleeve top
# 014635.json ---- item 2 ---- short sleeve top
# 014719.json ---- item 1 ---- short sleeve top
# 014726.json ---- item 1 ---- short sleeve top
# 014727.json ---- item 1 ---- short sleeve top
# 014729.json ---- item 1 ---- short sleeve top
# 014730.json ---- item 1 ---- short sleeve top
# 014732.json ---- item 1 ---- short sleeve top
# 014734.json ---- item 1 ---- short sleeve top
# 014807.json ---- item 1 ---- short sleeve top
# 014810.json ---- item 1 ---- short sleeve top
# 014811.json ---- item 1 ---- short sleeve top
# 014950.json ---- item 1 ---- short sleeve top
# 015078.json ---- item 1 ---- short sleeve top
# 015087.json ---- item 1 ---- short sleeve top
# 015128.json ---- item 1 ---- short sleeve top
# 015260.json ---- item 1 ---- short sleeve top
# 015417.json ---- item 1 ---- short sleeve top
# 015755.json ---- item 1 ---- short sleeve top
# 015759.json ---- item 1 ---- short sleeve top
# 015836.json ---- item 1 ---- short sleeve top
# 015838.json ---- item 1 ---- short sleeve top
# 015840.json ---- item 1 ---- short sleeve top
# 015956.json ---- item 1 ---- short sleeve top
# 015962.json ---- item 1 ---- short sleeve top
# 015963.json ---- item 1 ---- short sleeve top
# 015965.json ---- item 1 ---- short sleeve top
# 016003.json ---- item 1 ---- short sleeve top
# 016022.json ---- item 1 ---- short sleeve top
# 016179.json ---- item 1 ---- short sleeve top
# 016192.json ---- item 1 ---- short sleeve top
# 016195.json ---- item 1 ---- short sleeve top
# 016197.json ---- item 1 ---- short sleeve top
# 016203.json ---- item 1 ---- short sleeve top
# 016399.json ---- item 1 ---- short sleeve top
# 016410.json ---- item 1 ---- short sleeve top
# 016570.json ---- item 1 ---- short sleeve top
# 016646.json ---- item 1 ---- short sleeve top
# 016650.json ---- item 1 ---- short sleeve top
# 016680.json ---- item 1 ---- short sleeve top
# 016786.json ---- item 1 ---- short sleeve top
# 016806.json ---- item 1 ---- short sleeve top
# 016916.json ---- item 1 ---- short sleeve top
# 017027.json ---- item 1 ---- short sleeve top
# 017030.json ---- item 1 ---- short sleeve top
# 017032.json ---- item 1 ---- short sleeve top
# 017034.json ---- item 1 ---- short sleeve top
# 017036.json ---- item 1 ---- short sleeve top
# 017073.json ---- item 1 ---- short sleeve top
# 017079.json ---- item 1 ---- short sleeve top
# 017081.json ---- item 1 ---- short sleeve top
# 017082.json ---- item 1 ---- short sleeve top
# 017112.json ---- item 1 ---- short sleeve top
# 017118.json ---- item 1 ---- short sleeve top
# 017195.json ---- item 1 ---- short sleeve top
# 017217.json ---- item 1 ---- short sleeve top
# 017221.json ---- item 1 ---- short sleeve top
# 017223.json ---- item 1 ---- short sleeve top
# 017224.json ---- item 1 ---- short sleeve top
# 017303.json ---- item 1 ---- short sleeve top
# 017305.json ---- item 1 ---- short sleeve top
# 017320.json ---- item 2 ---- short sleeve top
# 017355.json ---- item 2 ---- short sleeve top
# 017454.json ---- item 1 ---- short sleeve top
# 017566.json ---- item 1 ---- short sleeve top
# 018032.json ---- item 1 ---- short sleeve top
# 018043.json ---- item 1 ---- short sleeve top
# 018045.json ---- item 1 ---- short sleeve top
# 018047.json ---- item 1 ---- short sleeve top
# 018049.json ---- item 1 ---- short sleeve top
# 018051.json ---- item 1 ---- short sleeve top
# 018053.json ---- item 1 ---- short sleeve top
# 018100.json ---- item 1 ---- short sleeve top
# 018102.json ---- item 1 ---- short sleeve top
# 018199.json ---- item 1 ---- short sleeve top
# 018203.json ---- item 1 ---- short sleeve top
# 018431.json ---- item 1 ---- short sleeve top
# 018433.json ---- item 1 ---- short sleeve top
# 018435.json ---- item 1 ---- short sleeve top
# 018437.json ---- item 1 ---- short sleeve top
# 018439.json ---- item 1 ---- short sleeve top
# 018443.json ---- item 1 ---- short sleeve top
# 018445.json ---- item 1 ---- short sleeve top
# 018459.json ---- item 1 ---- short sleeve top
# 018691.json ---- item 1 ---- short sleeve top
# 018694.json ---- item 1 ---- short sleeve top
# 018696.json ---- item 1 ---- short sleeve top
# 018799.json ---- item 1 ---- short sleeve top
# 018801.json ---- item 1 ---- short sleeve top
# 018803.json ---- item 1 ---- short sleeve top
# 018953.json ---- item 1 ---- short sleeve top
# 018957.json ---- item 1 ---- short sleeve top
# 019005.json ---- item 1 ---- short sleeve top
# 019007.json ---- item 1 ---- short sleeve top
# 019009.json ---- item 1 ---- short sleeve top
# 019014.json ---- item 1 ---- short sleeve top
# 019090.json ---- item 1 ---- short sleeve top
# 019092.json ---- item 1 ---- short sleeve top
# 019332.json ---- item 1 ---- short sleeve top
# 019526.json ---- item 1 ---- short sleeve top
# 019660.json ---- item 1 ---- short sleeve top
# 019759.json ---- item 1 ---- short sleeve top
# 019761.json ---- item 1 ---- short sleeve top
# 019932.json ---- item 1 ---- short sleeve top
# 019948.json ---- item 2 ---- short sleeve top
# 019969.json ---- item 2 ---- short sleeve top
# 020035.json ---- item 1 ---- short sleeve top
# 020037.json ---- item 1 ---- short sleeve top
# 020038.json ---- item 1 ---- short sleeve top
# 020040.json ---- item 1 ---- short sleeve top
# 020375.json ---- item 2 ---- short sleeve top
# 020387.json ---- item 1 ---- short sleeve top
# 020389.json ---- item 1 ---- short sleeve top
# 020405.json ---- item 1 ---- short sleeve top
# 020473.json ---- item 1 ---- short sleeve top
# 020524.json ---- item 2 ---- short sleeve top
# 020550.json ---- item 2 ---- short sleeve top
# 020564.json ---- item 2 ---- short sleeve top
# 020567.json ---- item 2 ---- short sleeve top
# 020569.json ---- item 2 ---- short sleeve top
# 020571.json ---- item 1 ---- short sleeve top
# 020577.json ---- item 1 ---- short sleeve top
# 020580.json ---- item 1 ---- short sleeve top
# 021130.json ---- item 1 ---- short sleeve top
# 021147.json ---- item 1 ---- short sleeve top
# 021151.json ---- item 2 ---- short sleeve top
# 021154.json ---- item 2 ---- short sleeve top
# 021226.json ---- item 1 ---- short sleeve top
# 021228.json ---- item 1 ---- short sleeve top
# 021229.json ---- item 1 ---- short sleeve top
# 021231.json ---- item 1 ---- short sleeve top
# 021236.json ---- item 1 ---- short sleeve top
# 021240.json ---- item 1 ---- short sleeve top
# 021242.json ---- item 1 ---- short sleeve top
# 021245.json ---- item 1 ---- short sleeve top
# 021247.json ---- item 1 ---- short sleeve top
# 021251.json ---- item 1 ---- short sleeve top
# 021310.json ---- item 1 ---- short sleeve top
# 021312.json ---- item 2 ---- short sleeve top
# 021314.json ---- item 1 ---- short sleeve top
# 021316.json ---- item 2 ---- short sleeve top
# 021318.json ---- item 2 ---- short sleeve top
# 021320.json ---- item 2 ---- short sleeve top
# 021393.json ---- item 1 ---- short sleeve top
# 021493.json ---- item 2 ---- short sleeve top
# 021521.json ---- item 1 ---- short sleeve top
# 021561.json ---- item 1 ---- short sleeve top
# 021738.json ---- item 1 ---- short sleeve top
# 022172.json ---- item 2 ---- short sleeve top
# 022176.json ---- item 2 ---- short sleeve top
# 022180.json ---- item 2 ---- short sleeve top
# 022314.json ---- item 1 ---- short sleeve top
# 022554.json ---- item 1 ---- short sleeve top
# 022560.json ---- item 1 ---- short sleeve top
# 022762.json ---- item 1 ---- short sleeve top
# 022764.json ---- item 2 ---- short sleeve top
# 022766.json ---- item 2 ---- short sleeve top
# 022768.json ---- item 2 ---- short sleeve top
# 022791.json ---- item 1 ---- short sleeve top
# 023962.json ---- item 1 ---- short sleeve top
# 025262.json ---- item 1 ---- short sleeve top
# 025275.json ---- item 2 ---- short sleeve top
# 025284.json ---- item 1 ---- short sleeve top
# 025413.json ---- item 1 ---- short sleeve top
# 025729.json ---- item 1 ---- short sleeve top
# 025731.json ---- item 1 ---- short sleeve top
# 025733.json ---- item 1 ---- short sleeve top
# 025734.json ---- item 1 ---- short sleeve top
# 025736.json ---- item 1 ---- short sleeve top
# 025740.json ---- item 1 ---- short sleeve top
# 025863.json ---- item 1 ---- short sleeve top
# 025934.json ---- item 1 ---- short sleeve top
# 025953.json ---- item 1 ---- short sleeve top
# 025960.json ---- item 1 ---- short sleeve top
# 025969.json ---- item 2 ---- short sleeve top
# 026012.json ---- item 1 ---- short sleeve top
# 026120.json ---- item 1 ---- short sleeve top
# 026527.json ---- item 1 ---- short sleeve top
# 026528.json ---- item 1 ---- short sleeve top
# 026670.json ---- item 1 ---- short sleeve top
# 027162.json ---- item 1 ---- short sleeve top
# 027536.json ---- item 1 ---- short sleeve top
# 027942.json ---- item 2 ---- short sleeve top
# 028099.json ---- item 1 ---- short sleeve top
# 028199.json ---- item 2 ---- short sleeve top
# 028542.json ---- item 1 ---- short sleeve top
# 028543.json ---- item 1 ---- short sleeve top
# 029147.json ---- item 2 ---- short sleeve top
# 029149.json ---- item 1 ---- short sleeve top
# 029159.json ---- item 2 ---- short sleeve top
# 029160.json ---- item 2 ---- short sleeve top
# 029162.json ---- item 2 ---- short sleeve top
# 029328.json ---- item 1 ---- short sleeve top
# 029330.json ---- item 1 ---- short sleeve top
# 029331.json ---- item 1 ---- short sleeve top
# 029340.json ---- item 1 ---- short sleeve top
# 029347.json ---- item 1 ---- short sleeve top
# 029349.json ---- item 1 ---- short sleeve top
# 029644.json ---- item 1 ---- short sleeve top
# 029646.json ---- item 1 ---- short sleeve top
# 029671.json ---- item 1 ---- short sleeve top
# 029674.json ---- item 1 ---- short sleeve top
# 029676.json ---- item 1 ---- short sleeve top
# 029717.json ---- item 1 ---- short sleeve top
# 029719.json ---- item 1 ---- short sleeve top
# 029840.json ---- item 1 ---- short sleeve top
# 029860.json ---- item 1 ---- short sleeve top
# 029942.json ---- item 1 ---- short sleeve top
# 030683.json ---- item 2 ---- short sleeve top
# 030780.json ---- item 1 ---- short sleeve top
# 030782.json ---- item 1 ---- short sleeve top
# 030894.json ---- item 1 ---- short sleeve top
# 030895.json ---- item 1 ---- short sleeve top
# 030920.json ---- item 1 ---- short sleeve top
# 031227.json ---- item 1 ---- short sleeve top
# 031231.json ---- item 1 ---- short sleeve top
# 031235.json ---- item 1 ---- short sleeve top
# 031237.json ---- item 1 ---- short sleeve top
# 031239.json ---- item 1 ---- short sleeve top
# 031265.json ---- item 1 ---- short sleeve top
# 031270.json ---- item 1 ---- short sleeve top
# 031285.json ---- item 2 ---- short sleeve top
# 031624.json ---- item 1 ---- short sleeve top
# []

# %%
# DeepFashion2의 COCO anno 를 Mask R-CNN의 VIA anno로 변환.
# 특정 카테고리의 하나의 인스턴스에 대해서만 작동함.
# anno_dir : DeepFashion2의 selected annotation 파일이 있는 directory
# image_dir : DeepFashion2의 selected image 파일이 있는 directory
# category_id : 추출하고자 하는 category_id
# save_anno_dir : 변환한 annotation을 저장할 directory
dutils.COCO_to_VIA(anno_dir=selected_anno_path, image_dir=selected_img_path, category_id=1, save_anno_dir=selected_img_path)

# %%
# train, val 나누기
train_path_img = 'C:/Users/chief/[2]FittingroomAnywhere2/Mask_RCNN/datasets/Tshirt_dataset/train/img'
train_path_anno = 'C:/Users/chief/[2]FittingroomAnywhere2/Mask_RCNN/datasets/Tshirt_dataset/train/anno'
val_path_img = 'C:/Users/chief/[2]FittingroomAnywhere2/Mask_RCNN/datasets/Tshirt_dataset/val/img'
val_path_anno = 'C:/Users/chief/[2]FittingroomAnywhere2/Mask_RCNN/datasets/Tshirt_dataset/val/anno'

# train set
dutils.anno_copy_by_img(train_path_img, original_path_anno, train_path_anno)
dutils.COCO_to_VIA(anno_dir=train_path_anno, image_dir=train_path_img, category_id=1, save_anno_dir=train_path_anno, mode="segmentation")
# test set
dutils.anno_copy_by_img(val_path_img, original_path_anno, val_path_anno)
dutils.COCO_to_VIA(anno_dir=val_path_anno, image_dir=val_path_img, category_id=1, save_anno_dir=val_path_anno, mode="segmentation")
